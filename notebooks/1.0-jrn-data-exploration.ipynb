# %%
import sys

from pathlib import Path

# Get the absolute path to the "src" directory
src_dir = (Path.cwd().parent / 'src').resolve()
sys.path.append(str(src_dir))

# %%
from utils import load_nifti_image
from visualizations import plot_brain_scans, plot_brain_scans_gif

# %%
# Load brain scan and lesion mask example
_, image = load_nifti_image('sub-00001_acq-T2sel_FLAIR.nii.gz')
_, mask = load_nifti_image('sub-00001_acq-T2sel_FLAIR_roi.nii.gz')

# %%
plot_brain_scans(image, mask, slice_index=150)

# %%
plot_brain_scans_gif(image, mask)
# Out:
# Animation saved as ../outputs/gifs/brain_scan.gif
